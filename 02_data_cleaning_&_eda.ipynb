# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import requests
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import re
from bs4 import BeautifulSoup
from tqdm import tqdm
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/jonathanbenton/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
songs = pd.read_csv('song_list')
songs.head(3)
# Out:
#    Unnamed: 0  Song ID Language                               Album  \
# 0           0     1533  English                        Almost There
# 1           1     1720  English  Lakewood Live: We Speak to Nations
# 2           2     1830  English                     Cover the Earth
#
#             Artist                          Authors  \
# 0          MercyMe                     Bart Millard
# 1  Lakewood Church                  Israel Houghton
# 2  Lakewood Church  Israel Houghton, Michael Gungor
#
#                      Arrangers                  Publishers CCLI Song #  \
# 0                Dan Galbraith  Essential Music Publishing     2978857
# 1  David Shipps, Dan Galbraith             Integrity Music     3383788
# 2                Dan Galbraith             Integrity Music     3991651
#
#       Tempo  ... Original Key Available Keys Meter        Source  \
# 0  Med Slow  ...            E       E, Eb, D   4/4  PraiseCharts
# 1      Fast  ...            E           E, F   4/4  PraiseCharts
# 2      Fast  ...            E           E, D   4/4  PraiseCharts
#
#                                               Themes  \
# 0  Abiding, Adoration, Alleluia, Awesome, Dance, ...
# 1  Adoration, Generation, Time, Endure, Tongue, N...
# 2  Adoration, Almighty, Amazing, Believe, Celebra...
#
#                                               lyrics                song  \
# 0  ['i can only imagine what it will be like, whe...  I Can Only Imagine
# 1  ['lord you are good and your mercy endureth fo...        You Are Good
# 2  ['intro', "in spite of all that we have done, ...       Friend Of God
#
#    year  Series Preferred Key
# 0  2004     NaN           NaN
# 1  2004     NaN           NaN
# 2  2004     NaN           NaN
#
# [3 rows x 21 columns]

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 674 entries, 0 to 673
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      674 non-null    int64
#  1   Song ID         674 non-null    int64
#  2   Language        674 non-null    object
#  3   Album           674 non-null    object
#  4   Artist          674 non-null    object
#  5   Authors         674 non-null    object
#  6   Arrangers       671 non-null    object
#  7   Publishers      612 non-null    object
#  8   CCLI Song #     673 non-null    object
#  9   Tempo           672 non-null    object
#  10  Style           629 non-null    object
#  11  Original Key    673 non-null    object
#  12  Available Keys  673 non-null    object
#  13  Meter           672 non-null    object
#  14  Source          463 non-null    object
#  15  Themes          674 non-null    object
#  16  lyrics          674 non-null    object
#  17  song            674 non-null    object
#  18  year            674 non-null    int64
#  19  Series          562 non-null    object
#  20  Preferred Key   39 non-null     object
# dtypes: int64(3), object(18)
# memory usage: 110.7+ KB

# %%
songs = songs[['song', 'Artist', 'lyrics', 'year', 'Style', 'Tempo', 'Meter', 'Themes']]
songs['song'].value_counts().head(40)
# Out:
# In Christ Alone                         16
# Amazing Grace (My Chains Are Gone)      11
# Joy To The World (Unspeakable Joy)      10
# 10000 Reasons (Bless The Lord)          10
# Jesus Paid It All                        9
# This Is Amazing Grace                    8
# Cornerstone                              8
# How Great Is Our God                     8
# Mighty To Save                           7
# You Are Good                             7
# O Praise The Name (Anastasis)            7
# Angels We Have Heard On High             6
# O Come All Ye Faithful                   6
# Lord I Need You                          6
# Lion And The Lamb                        6
# Revelation Song                          6
# Great Are You Lord                       6
# Your Grace Is Enough                     6
# Everlasting God                          6
# Hosanna (Praise Is Rising)               6
# Noel                                     5
# What A Beautiful Name (Live)             5
# Do It Again                              5
# Again I Say Rejoice                      5
# O Come To The Altar                      5
# Forever Reign                            5
# From The Inside Out                      5
# Our God                                  5
# It Is Well                               5
# Only King Forever                        4
# Oceans (Where Feet May Fail)             4
# I Am Free                                4
# Good Good Father                         4
# No Longer Slaves (Spontaneous)(Live)     4
# This I Believe (The Creed)               4
# Happy Day                                4
# Glorious Day (Living He Loved Me)        4
# Holy Spirit                              4
# I Heard The Bells On Christmas Day       4
# Forever                                  4
# Name: song, dtype: int64
